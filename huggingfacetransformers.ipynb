# %% [markdown]
# <a href="https://colab.research.google.com/github/AkhiTanu/gitlearning-genai-1/blob/main/huggingfacetransformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install transformers

# %%
from transformers import pipeline

# %%
analyser=pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# ...

# %%
data="i have been waiting so long to use google colab"

# %%
analyser(data)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9983545541763306}]

# %%
data="all of this waiting so long to use google colab"

# %%
summarizer=pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Device set to use cpu

# %%
data = "Transformers (stylised as TRANSFORMERS, alternatively titled as TransFormers, or simply abbreviated TF), is a media franchise produced by Japanese toy company Takara Tomy and American toy company Hasbro. It primarily follows the heroic Autobots and the villainous Decepticons, two alien robot factions at war that can transform into other forms, such as vehicles and animals. The franchise encompasses toys, animation, comic books, video games and films. As of 2011, it generated more than ¥2 trillion ($25 billion) in revenue,[1] making it one of the highest-grossing media franchises of all time."

# %%
response = summarizer(data, max_length = 56)

# %%
response[0]['summary_text']
# Out:
# ' As of 2011, it generated more than ¥2 trillion ($25 billion) in revenue . It is one of the highest-grossing media franchises of all time . The Transformers franchise is produced by Takara Tomy and American toy company Hasbro . It primarily follows'

# %%
# lets do model based nlp activities
model_id="facebook/bart-large-cnn"
data = """Branch specific pull request templates can be configured for pull requests that target a specific branch. To configure your repository with a branch specific pull request template, create a .txt or .md file named after your branch. The name must match the first level of the branch name, such as main, dev, release, or feature. Each branch specific pull request template is applied any time a pull request targets that branch or any branches contained under it. For example the pull request template named feature.md would be applied if a pull request targeted the feature branch or any feature/* branches.

Branch specific pull request templates must be saved in the default branch of your repository using the following folder hierarchy: pull_request_template/branches/. These folders must be based in one of the following folders in your repository.

A folder named .azuredevops that is contained in the root folder of the repository
A folder named .vsts that is contained in the root folder of the repository
A folder named docs that is contained in the root folder of the repository
The root folder of the repository
For example, a branch specific pull request template that should apply to all pull requests into the dev branch would be named dev.md or dev.txt and located in one of the following locations.

<repository root>/.azuredevops/pull_request_template/branches/
<repository root>/.vsts/pull_request_template/branches/
<repository root>/docs/pull_request_template/branches/
<repository root>/pull_request_template/branches/
Just like default pull request templates, multiple locations are provided to give you flexibility in where you store branch specific pull request templates. When a pull request is created, Azure Repos searches the designated folders in the order given for a branch specific pull request template, and uses the first one it finds that matches the branch name. If no branch specific pull request template is found, Azure Repos then searches for a default pull request template as described in the previous Default pull request templates section.
"""

# %%
summarizer = pipeline("summarization",model=model_id)
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu

# %%
summarizer(data, max_length=130, min_length=30, do_sample=False)
# Out:
# [{'summary_text': 'Branch specific pull request templates can be configured for pull requests that target a specific branch. The name must match the first level of the branch name, such as main, dev, release, or feature. These folders must be based in one of the following folders in your repository.'}]

# %%
question_answerer = pipeline("question-answering", model='distilbert-base-uncased-distilled-squad')
# Out:
# config.json:   0%|          | 0.00/451 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/265M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Device set to use cpu

# %%
story = """The sun beat down on the emerald meadow, where Ganga, a gentle cow with eyes the color of warm earth, grazed peacefully. Her bell tinkled softly as she moved, her tail swishing away the occasional fly. She was a creature of habit, content in her routine, the taste of sweet grass and the warmth of the sun all she desired.

On the other side of the whispering forest that bordered the meadow lived Bhairav, a tiger whose stripes were like shadows woven into gold. He was a creature of power and instinct, his every movement imbued with a silent grace and a latent threat. Hunger was his constant companion, and the rustling leaves and the distant calls of deer were the music of his hunt.

One sweltering afternoon, Ganga, drawn by the particularly succulent patch of clover near the edge of the forest, wandered further than usual. The shade of the tall trees offered a welcome respite from the harsh sun, and she munched contentedly, unaware of the amber eyes that watched her from the dense undergrowth.

Bhairav had been tracking a deer, but the scent had faded. Now, the sight of the plump, unsuspecting cow filled his senses. His muscles coiled, his body lowering to the ground, ready for the swift, decisive pounce that was his nature.

But as he tensed, a small sound caught his attention. A tiny, distressed bleating came from a thicket of thorny bushes near Ganga. Bhairav paused, his predatory focus momentarily broken. He saw a small calf, its leg caught in the thorny vines, struggling and whimpering.

Ganga, hearing her calf's cries, lifted her head, her peaceful demeanor instantly replaced by alarm. She bellowed, a deep, worried sound, and began to move towards the thicket, her eyes fixed on her trapped offspring.

Bhairav watched this unfold. He saw the mother's distress, the vulnerability of the trapped calf. A flicker of something other than hunger stirred within him, a primal understanding of a mother's protectiveness.

He could have easily sprung on Ganga then, her attention diverted. But the sight of her frantic efforts to reach her calf, the raw emotion in her cries, held him back. He remained still, a silent observer in the dappled sunlight.

Ganga, despite the sharp thorns that scratched her hide, managed to nudge and pull at the vines until, with a final tear, the calf was free. The little one stumbled out, bleating piteously, and immediately nuzzled against its mother's leg. Ganga licked its head reassuringly, her body a shield around her offspring.

Bhairav watched them, the hunter's instinct warring with a strange, unfamiliar feeling. He saw the relief in the cow's eyes, the tender connection between mother and child. In that moment, the cow was not just prey; she was a protector, a mother driven by love.

Slowly, Bhairav rose, his powerful body unfolding from its crouch. He turned away from the meadow, melting back into the shadows of the forest. The hunger was still there, a gnawing emptiness, but it was overshadowed by the image of the cow and her calf, their bond a silent testament to a force even stronger than the primal urge to hunt.

Ganga, after ensuring her calf was unharmed, led it back to the safety of the open meadow. She glanced once at the edge of the forest, a flicker of unease in her gentle eyes, but then returned to her grazing, the warmth of the sun and the soft tinkling of her bell a comforting rhythm in the afternoon quiet.

Neither Ganga nor Bhairav fully understood what had transpired at the edge of the forest that day. But in that brief encounter, a silent understanding had passed between them, a fleeting moment where the lines between predator and prey blurred, touched by the universal language of motherhood and a hint of something akin to respect. The forest and the meadow remained separate worlds, but for a little while, their boundaries had softened, and the ancient dance of survival had paused, yielding to a deeper, more profound truth.
"""

# %%
question_answerer(question="Where is the story happening?", context=story)
# Out:
# {'score': 0.08662257343530655,
#  'start': 21,
#  'end': 39,
#  'answer': 'the emerald meadow'}

# %%
question_answerer(question="Who is Bhairav?",context=story)
# Out:
# {'score': 0.6480541229248047, 'start': 407, 'end': 414, 'answer': 'a tiger'}

# %%
from transformers import AutoImageProcessor, AutoModelForImageClassification
import PIL
import requests

url = "https://pet-health-content-media.chewy.com/wp-content/uploads/2024/09/11181054/202104doberman-pinscher-dog-breed.jpg"
image = PIL.Image.open(requests.get(url, stream=True).raw)

image_processor = AutoImageProcessor.from_pretrained("wesleyacheng/dog-breeds-multiclass-image-classification-with-vit")
model = AutoModelForImageClassification.from_pretrained("wesleyacheng/dog-breeds-multiclass-image-classification-with-vit")

inputs = image_processor(images=image, return_tensors="pt")

outputs = model(**inputs)
logits = outputs.logits

# model predicts one of the 120 Stanford dog breeds classes
predicted_class_idx = logits.argmax(-1).item()
print("Predicted class:", model.config.id2label[predicted_class_idx])
# Out:
# preprocessor_config.json:   0%|          | 0.00/325 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# config.json:   0%|          | 0.00/6.75k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/344M [00:00<?, ?B/s]
# Predicted class: doberman
